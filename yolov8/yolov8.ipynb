# %% [markdown]
# # Modes
# #### Train,val, Predict
#
# # tasks
# #### detect, segment, classify
#
# # Data:
#
# #### Format can be differ for task type, Supports data.yaml, data_folder, data_name

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 877.6/877.6 kB 12.9 MB/s eta 0:00:00
# ...

# %%
# !pwd
# Out:
# /content

# %%
# !yolo task=detect mode=predict model=yolov8n.pt source='/content/2.jpg'
# Out:
# Ultralytics 8.3.23 🚀 Python-3.10.12 torch-2.5.0+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/2.jpg: 640x512 1 cat, 298.2ms
# Speed: 12.9ms preprocess, 298.2ms inference, 29.3ms postprocess per image at shape (1, 3, 640, 512)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=segment mode=predict model=yolov8n-seg.pt source='/content/2.jpg'
# Out:
# ...
# 100% 6.74M/6.74M [00:00<00:00, 26.0MB/s]
# Ultralytics 8.3.23 🚀 Python-3.10.12 torch-2.5.0+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n-seg summary (fused): 195 layers, 3,404,320 parameters, 0 gradients, 12.6 GFLOPs
#
# image 1/1 /content/2.jpg: 640x512 1 cat, 368.6ms
# Speed: 6.1ms preprocess, 368.6ms inference, 9.9ms postprocess per image at shape (1, 3, 640, 512)
# Results saved to runs/segment/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !wget https://ultralytics.com/assets/YOLOv8m-cls.pt
# Out:
# --2024-10-27 03:24:36--  https://ultralytics.com/assets/YOLOv8m-cls.pt
# Resolving ultralytics.com (ultralytics.com)... 99.83.190.102, 75.2.70.75
# Connecting to ultralytics.com (ultralytics.com)|99.83.190.102|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.ultralytics.com/assets/YOLOv8m-cls.pt [following]
# --2024-10-27 03:24:37--  https://www.ultralytics.com/assets/YOLOv8m-cls.pt
# Resolving www.ultralytics.com (www.ultralytics.com)... 172.64.147.154, 104.18.40.102, 2606:4700:4400::6812:2866, ...
# Connecting to www.ultralytics.com (www.ultralytics.com)|172.64.147.154|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://github.com/ultralytics/assets/releases/download/v0.0.0/YOLOv8m-cls.pt [following]
# --2024-10-27 03:24:38--  https://github.com/ultralytics/assets/releases/download/v0.0.0/YOLOv8m-cls.pt
# Resolving github.com (github.com)... 20.27.177.113
# ...

# %%
# !yolo task=classify mode=predict model=YOLOv8m-cls.pt source='/content/2.jpg'
# Out:
# Ultralytics 8.3.23 🚀 Python-3.10.12 torch-2.5.0+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8m-cls summary (fused): 103 layers, 17,043,656 parameters, 0 gradients, 42.7 GFLOPs
#
# ...
# 100% 755k/755k [00:00<00:00, 4.58MB/s]
# image 1/1 /content/2.jpg: 224x224 tabby 0.47, tiger_cat 0.25, Egyptian_cat 0.22, lynx 0.01, Persian_cat 0.01, 230.2ms
# Speed: 2.0ms preprocess, 230.2ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/classify/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# # Using python

# %%
from ultralytics import YOLO
model = YOLO('yolov8n.pt')
model.predict("/content/2.jpg",save=True)
# Out:
# image 1/1 /content/2.jpg: 640x512 1 cat, 245.9ms
# Speed: 5.2ms preprocess, 245.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
# Results saved to runs/detect/predict2
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...

# %%
from PIL import Image
Image.open("runs/detect/predict2/2.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=312x397>

# %%
model = YOLO('yolov8n-seg.pt')
model.predict("/content/2.jpg",save=True)
# Out:
# image 1/1 /content/2.jpg: 640x512 1 cat, 300.6ms
# Speed: 5.8ms preprocess, 300.6ms inference, 7.7ms postprocess per image at shape (1, 3, 640, 512)
# Results saved to runs/segment/predict2
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
# ...

# %%
model = YOLO('YOLOv8m-cls.pt')
model.predict("/content/2.jpg",save=True)
# Out:
# image 1/1 /content/2.jpg: 224x224 tabby 0.47, tiger_cat 0.25, Egyptian_cat 0.22, lynx 0.01, Persian_cat 0.01, 126.8ms
# Speed: 1.6ms preprocess, 126.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/classify/predict2
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: None
#  keypoints: None
#  masks: None
# ...
