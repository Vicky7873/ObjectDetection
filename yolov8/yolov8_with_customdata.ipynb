# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
# !unzip -q /content/data.zip -d data

# %%
import os
HOME = os.getcwd()
print (HOME)
# Out:
# /content

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 877.6/877.6 kB 21.4 MB/s eta 0:00:00
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.23 🚀 Python-3.10.12 torch-2.5.0+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.3/107.7 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !ls -a
# Out:
# .  ..  ch.mp4  .config	.data  data  data.zip

# %%
# !pwd
# Out:
# /content

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=data.yaml epochs=75 imgsz=416 batch=2
# Out:
# Ultralytics 8.3.23 🚀 Python-3.10.12 torch-2.5.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train5/weights/best.pt source=/content/data/data/test/images
# Out:
# Ultralytics 8.3.23 🚀 Python-3.10.12 torch-2.5.0+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/2 /content/data/data/test/images/22_jpg.rf.f75506b4b0c57b5c6a9537fc70b458ee.jpg: 416x416 2 chickens, 110.1ms
# image 2/2 /content/data/data/test/images/23_jpg.rf.a561392ec98237ce384394154009cf08.jpg: 416x416 3 chickens, 100.2ms
# Speed: 2.1ms preprocess, 105.2ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
Image("/content/runs/detect/predict2/22_jpg.rf.f75506b4b0c57b5c6a9537fc70b458ee.jpg")

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train5/weights/best.pt source=/content/ch.mp4
# Out:
# Ultralytics 8.3.23 🚀 Python-3.10.12 torch-2.5.0+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (frame 1/234) /content/ch.mp4: 256x416 6 chickens, 121.2ms
# video 1/1 (frame 2/234) /content/ch.mp4: 256x416 6 chickens, 102.2ms
# video 1/1 (frame 3/234) /content/ch.mp4: 256x416 6 chickens, 109.7ms
# video 1/1 (frame 4/234) /content/ch.mp4: 256x416 8 chickens, 69.6ms
# video 1/1 (frame 5/234) /content/ch.mp4: 256x416 7 chickens, 61.6ms
# video 1/1 (frame 6/234) /content/ch.mp4: 256x416 6 chickens, 63.1ms
# video 1/1 (frame 7/234) /content/ch.mp4: 256x416 6 chickens, 62.3ms
# video 1/1 (frame 8/234) /content/ch.mp4: 256x416 7 chickens, 62.7ms
# video 1/1 (frame 9/234) /content/ch.mp4: 256x416 6 chickens, 67.1ms
# video 1/1 (frame 10/234) /content/ch.mp4: 256x416 6 chickens, 62.5ms
# video 1/1 (frame 11/234) /content/ch.mp4: 256x416 7 chickens, 61.1ms
# ...
