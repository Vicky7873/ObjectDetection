# %%
import os

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.23 🚀 Python-3.10.15 torch-2.5.0 CPU (Apple M1)
# Setup complete ✅ (8 CPUs, 8.0 GB RAM, 161.9/228.3 GB disk)

# %%
# %pwd
# Out:
# '/Users/bhikipallai/Desktop/Projects/ObjectDetection/yolov11'

# %%
from ultralytics import YOLO

model = YOLO('yolo11n.pt')
result = model.train(
    data = '/Users/bhikipallai/Desktop/Projects/ObjectDetection/yolov11/chi.yaml',
    epochs = 13,
    imgsz = 416,
    batch = 2,
    device = 'mps'
)
# Out:
# Ultralytics 8.3.23 🚀 Python-3.10.15 torch-2.5.0 MPS (Apple M1)
# ...

# %%
from IPython.display import Image

# %%
Image('/Users/bhikipallai/Desktop/Projects/ObjectDetection/yolov11/runs/detect/train82/1_jpg.rf.4b4762e749f40598bd5dc25f7c0a3956.jpg')

# %%
model.predict('/Users/bhikipallai/Desktop/Projects/ObjectDetection/ch.mp4',save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/234) /Users/bhikipallai/Desktop/Projects/ObjectDetection/ch.mp4: 256x416 3 chickens, 3755.4ms
# video 1/1 (frame 2/234) /Users/bhikipallai/Desktop/Projects/ObjectDetection/ch.mp4: 256x416 3 chickens, 46.1ms
# video 1/1 (frame 3/234) /Users/bhikipallai/Desktop/Projects/ObjectDetection/ch.mp4: 256x416 2 chickens, 38.3ms
# ...
