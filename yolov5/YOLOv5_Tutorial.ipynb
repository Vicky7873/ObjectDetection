# %% [markdown]
# <div align="center">
#
#   <a href="https://ultralytics.com/yolov5" target="_blank">
#     <img width="1024", src="https://raw.githubusercontent.com/ultralytics/assets/main/yolov5/v70/splash.png"></a>
#
# [中文](https://docs.ultralytics.com/zh/) | [한국어](https://docs.ultralytics.com/ko/) | [日本語](https://docs.ultralytics.com/ja/) | [Русский](https://docs.ultralytics.com/ru/) | [Deutsch](https://docs.ultralytics.com/de/) | [Français](https://docs.ultralytics.com/fr/) | [Español](https://docs.ultralytics.com/es/) | [Português](https://docs.ultralytics.com/pt/) | [العربية](https://docs.ultralytics.com/ar/)
#
#   <a href="https://bit.ly/yolov5-paperspace-notebook"><img src="https://assets.paperspace.io/img/gradient-badge.svg" alt="Run on Gradient"></a>
#   <a href="https://colab.research.google.com/github/ultralytics/yolov5/blob/master/tutorial.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>
#   <a href="https://www.kaggle.com/models/ultralytics/yolov5"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" alt="Open In Kaggle"></a>
#
# This <a href="https://github.com/ultralytics/yolov5">YOLOv5</a> 🚀 notebook by <a href="https://ultralytics.com">Ultralytics</a> presents simple train, validate and predict examples to help start your AI adventure.<br>We hope that the resources in this notebook will help you get the most out of YOLOv5. Please browse the YOLOv5 <a href="https://docs.ultralytics.com/yolov5">Docs</a> for details, raise an issue on <a href="https://github.com/ultralytics/yolov5">GitHub</a> for support, and join our <a href="https://ultralytics.com/discord">Discord</a> community for questions and discussions!
#
# </div>

# %% [markdown]
# # Setup
#
# Clone GitHub [repository](https://github.com/ultralytics/yolov5), install [dependencies](https://github.com/ultralytics/yolov5/blob/master/requirements.txt) and check PyTorch and GPU.

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-378-g2f74455a Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.3/112.6 GB disk)

# %% [markdown]
# # 1. Detect
#
# `detect.py` runs YOLOv5 inference on a variety of sources, downloading models automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases), and saving results to `runs/detect`. Example inference sources are:
#
# ```shell
# python detect.py --source 0  # webcam
#                           img.jpg  # image
#                           vid.mp4  # video
#                           screen  # screenshot
#                           path/  # directory
#                          'path/*.jpg'  # glob
#                          'https://youtu.be/LNwODJXcvt4'  # YouTube
#                          'rtsp://example.com/media.mp4'  # RTSP, RTMP, HTTP stream
# ```

# %%
# !python detect.py --weights runs/train/exp3/weights/best.pt --img 640 --conf 0.25 --source /content/ch.mp4
# display.Image(filename='runs/detect/exp/zidane.jpg', width=600)
# Out:
# detect: weights=['runs/train/exp3/weights/best.pt'], source=/content/ch.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-378-g2f74455a Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/234) /content/ch.mp4: 384x640 8 chickens, 28.3ms
# video 1/1 (2/234) /content/ch.mp4: 384x640 8 chickens, 7.8ms
# video 1/1 (3/234) /content/ch.mp4: 384x640 8 chickens, 7.5ms
# video 1/1 (4/234) /content/ch.mp4: 384x640 6 chickens, 7.5ms
# video 1/1 (5/234) /content/ch.mp4: 384x640 8 chickens, 7.5ms
# video 1/1 (6/234) /content/ch.mp4: 384x640 8 chickens, 7.5ms
# video 1/1 (7/234) /content/ch.mp4: 384x640 7 chickens, 7.5ms
# video 1/1 (8/234) /content/ch.mp4: 384x640 7 chickens, 10.4ms
# video 1/1 (9/234) /content/ch.mp4: 384x640 6 chickens, 7.5ms
# video 1/1 (10/234) /content/ch.mp4: 384x640 6 chickens, 7.5ms
# video 1/1 (11/234) /content/ch.mp4: 384x640 6 chickens, 8.2ms
# video 1/1 (12/234) /content/ch.mp4: 384x640 6 chickens, 7.5ms
# video 1/1 (13/234) /content/ch.mp4: 384x640 6 chickens, 10.4ms
# video 1/1 (14/234) /content/ch.mp4: 384x640 7 chickens, 7.6ms
# video 1/1 (15/234) /content/ch.mp4: 384x640 6 chickens, 12.3ms
# video 1/1 (16/234) /content/ch.mp4: 384x640 7 chickens, 7.5ms
# video 1/1 (17/234) /content/ch.mp4: 384x640 7 chickens, 7.5ms
# video 1/1 (18/234) /content/ch.mp4: 384x640 7 chickens, 7.5ms
# video 1/1 (19/234) /content/ch.mp4: 384x640 7 chickens, 7.5ms
# video 1/1 (20/234) /content/ch.mp4: 384x640 7 chickens, 7.5ms
# video 1/1 (21/234) /content/ch.mp4: 384x640 5 chickens, 7.5ms
# video 1/1 (22/234) /content/ch.mp4: 384x640 5 chickens, 10.3ms
# video 1/1 (23/234) /content/ch.mp4: 384x640 5 chickens, 7.5ms
# video 1/1 (24/234) /content/ch.mp4: 384x640 6 chickens, 7.5ms
# video 1/1 (25/234) /content/ch.mp4: 384x640 5 chickens, 7.5ms
# video 1/1 (26/234) /content/ch.mp4: 384x640 6 chickens, 7.5ms
# video 1/1 (27/234) /content/ch.mp4: 384x640 5 chickens, 7.6ms
# video 1/1 (28/234) /content/ch.mp4: 384x640 5 chickens, 7.5ms
# video 1/1 (29/234) /content/ch.mp4: 384x640 5 chickens, 7.5ms
# video 1/1 (30/234) /content/ch.mp4: 384x640 5 chickens, 7.5ms
# video 1/1 (31/234) /content/ch.mp4: 384x640 7 chickens, 7.5ms
# video 1/1 (32/234) /content/ch.mp4: 384x640 6 chickens, 10.9ms
# video 1/1 (33/234) /content/ch.mp4: 384x640 7 chickens, 7.5ms
# video 1/1 (34/234) /content/ch.mp4: 384x640 8 chickens, 7.5ms
# video 1/1 (35/234) /content/ch.mp4: 384x640 8 chickens, 7.5ms
# video 1/1 (36/234) /content/ch.mp4: 384x640 7 chickens, 7.5ms
# video 1/1 (37/234) /content/ch.mp4: 384x640 8 chickens, 7.5ms
# video 1/1 (38/234) /content/ch.mp4: 384x640 8 chickens, 7.5ms
# video 1/1 (39/234) /content/ch.mp4: 384x640 6 chickens, 10.5ms
# video 1/1 (40/234) /content/ch.mp4: 384x640 6 chickens, 7.5ms
# video 1/1 (41/234) /content/ch.mp4: 384x640 7 chickens, 9.8ms
# video 1/1 (42/234) /content/ch.mp4: 384x640 7 chickens, 7.6ms
# video 1/1 (43/234) /content/ch.mp4: 384x640 8 chickens, 9.8ms
# video 1/1 (44/234) /content/ch.mp4: 384x640 7 chickens, 12.5ms
# video 1/1 (45/234) /content/ch.mp4: 384x640 7 chickens, 7.5ms
# video 1/1 (46/234) /content/ch.mp4: 384x640 7 chickens, 7.5ms
# video 1/1 (47/234) /content/ch.mp4: 384x640 7 chickens, 12.6ms
# video 1/1 (48/234) /content/ch.mp4: 384x640 7 chickens, 7.5ms
# video 1/1 (49/234) /content/ch.mp4: 384x640 8 chickens, 8.3ms
# video 1/1 (50/234) /content/ch.mp4: 384x640 8 chickens, 7.8ms
# video 1/1 (51/234) /content/ch.mp4: 384x640 8 chickens, 7.8ms
# video 1/1 (52/234) /content/ch.mp4: 384x640 8 chickens, 7.5ms
# video 1/1 (53/234) /content/ch.mp4: 384x640 8 chickens, 7.5ms
# video 1/1 (54/234) /content/ch.mp4: 384x640 8 chickens, 7.5ms
# video 1/1 (55/234) /content/ch.mp4: 384x640 7 chickens, 9.9ms
# video 1/1 (56/234) /content/ch.mp4: 384x640 7 chickens, 7.5ms
# video 1/1 (57/234) /content/ch.mp4: 384x640 7 chickens, 7.5ms
# video 1/1 (58/234) /content/ch.mp4: 384x640 7 chickens, 7.5ms
# video 1/1 (59/234) /content/ch.mp4: 384x640 8 chickens, 7.6ms
# video 1/1 (60/234) /content/ch.mp4: 384x640 8 chickens, 7.5ms
# video 1/1 (61/234) /content/ch.mp4: 384x640 7 chickens, 7.5ms
# video 1/1 (62/234) /content/ch.mp4: 384x640 8 chickens, 7.5ms
# video 1/1 (63/234) /content/ch.mp4: 384x640 8 chickens, 7.6ms
# video 1/1 (64/234) /content/ch.mp4: 384x640 7 chickens, 7.5ms
# video 1/1 (65/234) /content/ch.mp4: 384x640 6 chickens, 7.5ms
# video 1/1 (66/234) /content/ch.mp4: 384x640 7 chickens, 7.6ms
# video 1/1 (67/234) /content/ch.mp4: 384x640 8 chickens, 9.2ms
# video 1/1 (68/234) /content/ch.mp4: 384x640 6 chickens, 9.3ms
# video 1/1 (69/234) /content/ch.mp4: 384x640 5 chickens, 7.5ms
# video 1/1 (70/234) /content/ch.mp4: 384x640 7 chickens, 7.5ms
# video 1/1 (71/234) /content/ch.mp4: 384x640 7 chickens, 8.1ms
# video 1/1 (72/234) /content/ch.mp4: 384x640 7 chickens, 7.5ms
# video 1/1 (73/234) /content/ch.mp4: 384x640 7 chickens, 7.8ms
# video 1/1 (74/234) /content/ch.mp4: 384x640 7 chickens, 7.5ms
# video 1/1 (75/234) /content/ch.mp4: 384x640 7 chickens, 9.0ms
# video 1/1 (76/234) /content/ch.mp4: 384x640 7 chickens, 7.5ms
# video 1/1 (77/234) /content/ch.mp4: 384x640 6 chickens, 7.5ms
# video 1/1 (78/234) /content/ch.mp4: 384x640 7 chickens, 7.5ms
# video 1/1 (79/234) /content/ch.mp4: 384x640 7 chickens, 7.7ms
# video 1/1 (80/234) /content/ch.mp4: 384x640 7 chickens, 7.5ms
# video 1/1 (81/234) /content/ch.mp4: 384x640 6 chickens, 8.4ms
# video 1/1 (82/234) /content/ch.mp4: 384x640 6 chickens, 7.5ms
# video 1/1 (83/234) /content/ch.mp4: 384x640 5 chickens, 7.6ms
# video 1/1 (84/234) /content/ch.mp4: 384x640 7 chickens, 7.5ms
# video 1/1 (85/234) /content/ch.mp4: 384x640 7 chickens, 7.5ms
# video 1/1 (86/234) /content/ch.mp4: 384x640 5 chickens, 7.5ms
# video 1/1 (87/234) /content/ch.mp4: 384x640 4 chickens, 20.4ms
# video 1/1 (88/234) /content/ch.mp4: 384x640 4 chickens, 8.0ms
# video 1/1 (89/234) /content/ch.mp4: 384x640 4 chickens, 7.5ms
# video 1/1 (90/234) /content/ch.mp4: 384x640 5 chickens, 7.5ms
# video 1/1 (91/234) /content/ch.mp4: 384x640 5 chickens, 7.5ms
# video 1/1 (92/234) /content/ch.mp4: 384x640 5 chickens, 7.5ms
# video 1/1 (93/234) /content/ch.mp4: 384x640 7 chickens, 7.6ms
# video 1/1 (94/234) /content/ch.mp4: 384x640 7 chickens, 7.5ms
# video 1/1 (95/234) /content/ch.mp4: 384x640 7 chickens, 7.5ms
# video 1/1 (96/234) /content/ch.mp4: 384x640 5 chickens, 7.5ms
# video 1/1 (97/234) /content/ch.mp4: 384x640 5 chickens, 7.7ms
# video 1/1 (98/234) /content/ch.mp4: 384x640 7 chickens, 10.0ms
# video 1/1 (99/234) /content/ch.mp4: 384x640 5 chickens, 7.5ms
# video 1/1 (100/234) /content/ch.mp4: 384x640 6 chickens, 7.5ms
# video 1/1 (101/234) /content/ch.mp4: 384x640 6 chickens, 7.9ms
# video 1/1 (102/234) /content/ch.mp4: 384x640 6 chickens, 7.6ms
# video 1/1 (103/234) /content/ch.mp4: 384x640 7 chickens, 7.5ms
# video 1/1 (104/234) /content/ch.mp4: 384x640 5 chickens, 7.5ms
# video 1/1 (105/234) /content/ch.mp4: 384x640 5 chickens, 7.8ms
# video 1/1 (106/234) /content/ch.mp4: 384x640 4 chickens, 7.8ms
# video 1/1 (107/234) /content/ch.mp4: 384x640 5 chickens, 9.4ms
# video 1/1 (108/234) /content/ch.mp4: 384x640 5 chickens, 7.5ms
# video 1/1 (109/234) /content/ch.mp4: 384x640 5 chickens, 7.8ms
# video 1/1 (110/234) /content/ch.mp4: 384x640 5 chickens, 9.7ms
# video 1/1 (111/234) /content/ch.mp4: 384x640 5 chickens, 7.5ms
# video 1/1 (112/234) /content/ch.mp4: 384x640 5 chickens, 7.5ms
# video 1/1 (113/234) /content/ch.mp4: 384x640 5 chickens, 7.5ms
# video 1/1 (114/234) /content/ch.mp4: 384x640 5 chickens, 7.5ms
# video 1/1 (115/234) /content/ch.mp4: 384x640 4 chickens, 7.5ms
# video 1/1 (116/234) /content/ch.mp4: 384x640 4 chickens, 7.5ms
# video 1/1 (117/234) /content/ch.mp4: 384x640 4 chickens, 7.9ms
# video 1/1 (118/234) /content/ch.mp4: 384x640 5 chickens, 7.5ms
# video 1/1 (119/234) /content/ch.mp4: 384x640 5 chickens, 7.6ms
# video 1/1 (120/234) /content/ch.mp4: 384x640 6 chickens, 10.8ms
# video 1/1 (121/234) /content/ch.mp4: 384x640 6 chickens, 10.4ms
# video 1/1 (122/234) /content/ch.mp4: 384x640 6 chickens, 10.3ms
# video 1/1 (123/234) /content/ch.mp4: 384x640 6 chickens, 7.5ms
# video 1/1 (124/234) /content/ch.mp4: 384x640 6 chickens, 12.3ms
# video 1/1 (125/234) /content/ch.mp4: 384x640 5 chickens, 11.4ms
# video 1/1 (126/234) /content/ch.mp4: 384x640 4 chickens, 7.7ms
# video 1/1 (127/234) /content/ch.mp4: 384x640 4 chickens, 8.5ms
# video 1/1 (128/234) /content/ch.mp4: 384x640 4 chickens, 7.9ms
# video 1/1 (129/234) /content/ch.mp4: 384x640 5 chickens, 7.9ms
# video 1/1 (130/234) /content/ch.mp4: 384x640 5 chickens, 8.9ms
# video 1/1 (131/234) /content/ch.mp4: 384x640 6 chickens, 7.6ms
# video 1/1 (132/234) /content/ch.mp4: 384x640 4 chickens, 7.6ms
# video 1/1 (133/234) /content/ch.mp4: 384x640 6 chickens, 10.1ms
# video 1/1 (134/234) /content/ch.mp4: 384x640 6 chickens, 7.5ms
# video 1/1 (135/234) /content/ch.mp4: 384x640 6 chickens, 7.7ms
# video 1/1 (136/234) /content/ch.mp4: 384x640 7 chickens, 7.7ms
# video 1/1 (137/234) /content/ch.mp4: 384x640 6 chickens, 7.7ms
# video 1/1 (138/234) /content/ch.mp4: 384x640 6 chickens, 7.6ms
# video 1/1 (139/234) /content/ch.mp4: 384x640 6 chickens, 9.6ms
# video 1/1 (140/234) /content/ch.mp4: 384x640 5 chickens, 7.5ms
# video 1/1 (141/234) /content/ch.mp4: 384x640 7 chickens, 10.1ms
# video 1/1 (142/234) /content/ch.mp4: 384x640 6 chickens, 7.8ms
# video 1/1 (143/234) /content/ch.mp4: 384x640 8 chickens, 7.5ms
# video 1/1 (144/234) /content/ch.mp4: 384x640 7 chickens, 7.5ms
# video 1/1 (145/234) /content/ch.mp4: 384x640 6 chickens, 10.5ms
# video 1/1 (146/234) /content/ch.mp4: 384x640 6 chickens, 13.6ms
# video 1/1 (147/234) /content/ch.mp4: 384x640 7 chickens, 7.5ms
# video 1/1 (148/234) /content/ch.mp4: 384x640 7 chickens, 7.5ms
# video 1/1 (149/234) /content/ch.mp4: 384x640 6 chickens, 7.5ms
# video 1/1 (150/234) /content/ch.mp4: 384x640 6 chickens, 7.5ms
# video 1/1 (151/234) /content/ch.mp4: 384x640 5 chickens, 8.3ms
# video 1/1 (152/234) /content/ch.mp4: 384x640 6 chickens, 9.0ms
# video 1/1 (153/234) /content/ch.mp4: 384x640 5 chickens, 16.0ms
# video 1/1 (154/234) /content/ch.mp4: 384x640 5 chickens, 10.6ms
# video 1/1 (155/234) /content/ch.mp4: 384x640 5 chickens, 8.2ms
# video 1/1 (156/234) /content/ch.mp4: 384x640 6 chickens, 10.4ms
# video 1/1 (157/234) /content/ch.mp4: 384x640 6 chickens, 7.9ms
# video 1/1 (158/234) /content/ch.mp4: 384x640 6 chickens, 10.7ms
# video 1/1 (159/234) /content/ch.mp4: 384x640 5 chickens, 8.0ms
# video 1/1 (160/234) /content/ch.mp4: 384x640 5 chickens, 11.8ms
# video 1/1 (161/234) /content/ch.mp4: 384x640 5 chickens, 7.5ms
# video 1/1 (162/234) /content/ch.mp4: 384x640 5 chickens, 7.5ms
# video 1/1 (163/234) /content/ch.mp4: 384x640 4 chickens, 10.9ms
# video 1/1 (164/234) /content/ch.mp4: 384x640 4 chickens, 10.7ms
# video 1/1 (165/234) /content/ch.mp4: 384x640 4 chickens, 13.4ms
# video 1/1 (166/234) /content/ch.mp4: 384x640 4 chickens, 14.3ms
# video 1/1 (167/234) /content/ch.mp4: 384x640 5 chickens, 8.7ms
# video 1/1 (168/234) /content/ch.mp4: 384x640 5 chickens, 8.0ms
# video 1/1 (169/234) /content/ch.mp4: 384x640 4 chickens, 10.4ms
# video 1/1 (170/234) /content/ch.mp4: 384x640 5 chickens, 9.5ms
# video 1/1 (171/234) /content/ch.mp4: 384x640 4 chickens, 10.2ms
# video 1/1 (172/234) /content/ch.mp4: 384x640 5 chickens, 11.5ms
# video 1/1 (173/234) /content/ch.mp4: 384x640 5 chickens, 13.3ms
# video 1/1 (174/234) /content/ch.mp4: 384x640 5 chickens, 9.5ms
# video 1/1 (175/234) /content/ch.mp4: 384x640 4 chickens, 9.9ms
# video 1/1 (176/234) /content/ch.mp4: 384x640 4 chickens, 9.9ms
# video 1/1 (177/234) /content/ch.mp4: 384x640 5 chickens, 9.7ms
# video 1/1 (178/234) /content/ch.mp4: 384x640 4 chickens, 27.2ms
# video 1/1 (179/234) /content/ch.mp4: 384x640 4 chickens, 14.6ms
# video 1/1 (180/234) /content/ch.mp4: 384x640 4 chickens, 13.9ms
# video 1/1 (181/234) /content/ch.mp4: 384x640 4 chickens, 14.6ms
# video 1/1 (182/234) /content/ch.mp4: 384x640 4 chickens, 9.1ms
# video 1/1 (183/234) /content/ch.mp4: 384x640 4 chickens, 8.6ms
# video 1/1 (184/234) /content/ch.mp4: 384x640 4 chickens, 8.8ms
# video 1/1 (185/234) /content/ch.mp4: 384x640 4 chickens, 8.9ms
# video 1/1 (186/234) /content/ch.mp4: 384x640 4 chickens, 8.8ms
# video 1/1 (187/234) /content/ch.mp4: 384x640 4 chickens, 9.0ms
# video 1/1 (188/234) /content/ch.mp4: 384x640 4 chickens, 8.4ms
# video 1/1 (189/234) /content/ch.mp4: 384x640 5 chickens, 11.7ms
# video 1/1 (190/234) /content/ch.mp4: 384x640 4 chickens, 8.4ms
# video 1/1 (191/234) /content/ch.mp4: 384x640 5 chickens, 8.4ms
# video 1/1 (192/234) /content/ch.mp4: 384x640 4 chickens, 11.1ms
# video 1/1 (193/234) /content/ch.mp4: 384x640 4 chickens, 8.5ms
# video 1/1 (194/234) /content/ch.mp4: 384x640 5 chickens, 8.4ms
# video 1/1 (195/234) /content/ch.mp4: 384x640 4 chickens, 8.4ms
# video 1/1 (196/234) /content/ch.mp4: 384x640 4 chickens, 8.6ms
# video 1/1 (197/234) /content/ch.mp4: 384x640 4 chickens, 8.4ms
# video 1/1 (198/234) /content/ch.mp4: 384x640 4 chickens, 8.4ms
# video 1/1 (199/234) /content/ch.mp4: 384x640 4 chickens, 8.5ms
# video 1/1 (200/234) /content/ch.mp4: 384x640 5 chickens, 8.4ms
# video 1/1 (201/234) /content/ch.mp4: 384x640 5 chickens, 8.7ms
# video 1/1 (202/234) /content/ch.mp4: 384x640 5 chickens, 8.3ms
# video 1/1 (203/234) /content/ch.mp4: 384x640 5 chickens, 8.5ms
# video 1/1 (204/234) /content/ch.mp4: 384x640 4 chickens, 13.8ms
# video 1/1 (205/234) /content/ch.mp4: 384x640 4 chickens, 8.7ms
# video 1/1 (206/234) /content/ch.mp4: 384x640 4 chickens, 8.9ms
# video 1/1 (207/234) /content/ch.mp4: 384x640 4 chickens, 10.5ms
# video 1/1 (208/234) /content/ch.mp4: 384x640 4 chickens, 10.8ms
# video 1/1 (209/234) /content/ch.mp4: 384x640 4 chickens, 14.1ms
# video 1/1 (210/234) /content/ch.mp4: 384x640 4 chickens, 12.4ms
# video 1/1 (211/234) /content/ch.mp4: 384x640 4 chickens, 11.6ms
# video 1/1 (212/234) /content/ch.mp4: 384x640 4 chickens, 10.3ms
# video 1/1 (213/234) /content/ch.mp4: 384x640 4 chickens, 11.8ms
# video 1/1 (214/234) /content/ch.mp4: 384x640 5 chickens, 10.5ms
# video 1/1 (215/234) /content/ch.mp4: 384x640 5 chickens, 9.2ms
# video 1/1 (216/234) /content/ch.mp4: 384x640 5 chickens, 11.4ms
# video 1/1 (217/234) /content/ch.mp4: 384x640 5 chickens, 10.9ms
# video 1/1 (218/234) /content/ch.mp4: 384x640 5 chickens, 10.2ms
# video 1/1 (219/234) /content/ch.mp4: 384x640 5 chickens, 7.5ms
# video 1/1 (220/234) /content/ch.mp4: 384x640 5 chickens, 7.5ms
# video 1/1 (221/234) /content/ch.mp4: 384x640 5 chickens, 7.5ms
# video 1/1 (222/234) /content/ch.mp4: 384x640 4 chickens, 8.6ms
# video 1/1 (223/234) /content/ch.mp4: 384x640 4 chickens, 7.5ms
# video 1/1 (224/234) /content/ch.mp4: 384x640 4 chickens, 7.5ms
# video 1/1 (225/234) /content/ch.mp4: 384x640 4 chickens, 7.5ms
# video 1/1 (226/234) /content/ch.mp4: 384x640 4 chickens, 7.5ms
# video 1/1 (227/234) /content/ch.mp4: 384x640 4 chickens, 7.5ms
# video 1/1 (228/234) /content/ch.mp4: 384x640 4 chickens, 7.5ms
# video 1/1 (229/234) /content/ch.mp4: 384x640 5 chickens, 7.5ms
# video 1/1 (230/234) /content/ch.mp4: 384x640 5 chickens, 9.0ms
# video 1/1 (231/234) /content/ch.mp4: 384x640 4 chickens, 7.5ms
# video 1/1 (232/234) /content/ch.mp4: 384x640 4 chickens, 7.4ms
# video 1/1 (233/234) /content/ch.mp4: 384x640 4 chickens, 7.5ms
# video 1/1 (234/234) /content/ch.mp4: 384x640 3 chickens, 7.4ms
# Speed: 0.4ms pre-process, 8.9ms inference, 3.6ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp9

# %% [markdown]
# # 2. Validate
# Validate a model's accuracy on the [COCO](https://cocodataset.org/#home) dataset's `val` or `test` splits. Models are downloaded automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases). To show results by class use the `--verbose` flag.

# %%
# Download COCO val
# torch.hub.download_url_to_file('https://github.com/ultralytics/assets/releases/download/v0.0.0/coco2017val.zip', 'tmp.zip')  # download (780M - 5000 images)
# !unzip -q /content/data.zip -d ./data # unzip

# %%
# %pwd
# Out:
# '/content/yolov5'

# %% [markdown]
# # 3. Train
#
# <p align=""><a href="https://ultralytics.com/hub"><img width="1000" src="https://github.com/ultralytics/assets/raw/main/im/integrations-loop.png"/></a></p>
# Close the active learning loop by sampling images from your inference conditions with the `roboflow` pip package
# <br><br>
#
# Train a YOLOv5s model on the [COCO128](https://www.kaggle.com/datasets/ultralytics/coco128) dataset with `--data coco128.yaml`, starting from pretrained `--weights yolov5s.pt`, or from randomly initialized `--weights '' --cfg yolov5s.yaml`.
#
# - **Pretrained [Models](https://github.com/ultralytics/yolov5/tree/master/models)** are downloaded
# automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases)
# - **[Datasets](https://github.com/ultralytics/yolov5/tree/master/data)** available for autodownload include: [COCO](https://github.com/ultralytics/yolov5/blob/master/data/coco.yaml), [COCO128](https://github.com/ultralytics/yolov5/blob/master/data/coco128.yaml), [VOC](https://github.com/ultralytics/yolov5/blob/master/data/VOC.yaml), [Argoverse](https://github.com/ultralytics/yolov5/blob/master/data/Argoverse.yaml), [VisDrone](https://github.com/ultralytics/yolov5/blob/master/data/VisDrone.yaml), [GlobalWheat](https://github.com/ultralytics/yolov5/blob/master/data/GlobalWheat2020.yaml), [xView](https://github.com/ultralytics/yolov5/blob/master/data/xView.yaml), [Objects365](https://github.com/ultralytics/yolov5/blob/master/data/Objects365.yaml), [SKU-110K](https://github.com/ultralytics/yolov5/blob/master/data/SKU-110K.yaml).
# - **Training Results** are saved to `runs/train/` with incrementing run directories, i.e. `runs/train/exp2`, `runs/train/exp3` etc.
# <br>
#
# A **Mosaic Dataloader** is used for training which combines 4 images into 1 mosaic.
#
# ## Label a dataset on Roboflow (optional)
#
# [Roboflow](https://roboflow.com/?ref=ultralytics) enables you to easily **organize, label, and prepare** a high quality dataset with your own custom data. Roboflow also makes it easy to establish an active learning pipeline, collaborate with your team on dataset improvement, and integrate directly into your model building workflow with the `roboflow` pip package.

# %%
#@title Select YOLOv5 🚀 logger {run: 'auto'}
# logger = 'Comet' #@param ['Comet', 'ClearML', 'TensorBoard']

# if logger == 'Comet':
#   %pip install -q comet_ml
#   import comet_ml; comet_ml.init()
# elif logger == 'ClearML':
#   %pip install -q clearml
#   import clearml; clearml.browser_login()
# elif logger == 'TensorBoard':
#   %load_ext tensorboard
#   %tensorboard --logdir runs/train

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 640 --batch 2 --epochs 75 --data data.yaml --weights yolov5s.pt --cache
# Out:
# Streaming output truncated to the last 5000 lines.
#   with torch.cuda.amp.autocast(amp):
#        4/74     0.726G    0.06193    0.03747          0         10        640:  81%|████████▏ | 26/32 [00:03<00:00,  7.86it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        4/74     0.726G     0.0605    0.03675          0          4        640:  84%|████████▍ | 27/32 [00:03<00:00,  8.14it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        4/74     0.726G    0.06011    0.03671          0          9        640:  88%|████████▊ | 28/32 [00:03<00:00,  8.44it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        4/74     0.726G    0.05949    0.03684          0         10        640:  91%|█████████ | 29/32 [00:04<00:00,  8.25it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        4/74     0.726G    0.06102    0.03698          0         12        640:  94%|█████████▍| 30/32 [00:04<00:00,  8.12it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        4/74     0.726G    0.06106    0.03686          0          9        640:  97%|█████████▋| 31/32 [00:04<00:00,  8.00it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        4/74     0.726G    0.06097    0.03743          0          7        640: 100%|██████████| 32/32 [00:04<00:00,  7.31it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 2/2 [00:00<00:00, 10.44it/s]
#                    all          7         17      0.569      0.706      0.612      0.192
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/32 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/74     0.726G     0.0793    0.03317          0          8        640:   0%|          | 0/32 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/74     0.726G    0.08899    0.04609          0         14        640:   6%|▋         | 2/32 [00:00<00:02, 12.51it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/74     0.726G    0.07265    0.03667          0          3        640:   6%|▋         | 2/32 [00:00<00:02, 12.51it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/74     0.726G    0.06587    0.03365          0          6        640:  12%|█▎        | 4/32 [00:00<00:02, 12.53it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/74     0.726G    0.06348    0.03674          0         12        640:  12%|█▎        | 4/32 [00:00<00:02, 12.53it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/74     0.726G    0.06213    0.03611          0          7        640:  19%|█▉        | 6/32 [00:00<00:02, 12.83it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/74     0.726G    0.06172     0.0347          0          7        640:  19%|█▉        | 6/32 [00:00<00:02, 12.83it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/74     0.726G    0.06394    0.03758          0         17        640:  25%|██▌       | 8/32 [00:00<00:01, 12.93it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/74     0.726G    0.06533    0.03849          0         13        640:  25%|██▌       | 8/32 [00:00<00:01, 12.93it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/74     0.726G    0.06457    0.03778          0          8        640:  31%|███▏      | 10/32 [00:00<00:01, 13.39it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/74     0.726G    0.06521    0.03873          0         12        640:  31%|███▏      | 10/32 [00:00<00:01, 13.39it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/74     0.726G    0.06448    0.03894          0         11        640:  38%|███▊      | 12/32 [00:00<00:01, 13.26it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/74     0.726G    0.06324    0.03857          0          9        640:  38%|███▊      | 12/32 [00:00<00:01, 13.26it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/74     0.726G    0.06599    0.03766          0          6        640:  44%|████▍     | 14/32 [00:01<00:01, 13.37it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/74     0.726G     0.0646    0.03641          0          4        640:  44%|████▍     | 14/32 [00:01<00:01, 13.37it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/74     0.726G    0.06401    0.03677          0         12        640:  50%|█████     | 16/32 [00:01<00:01, 12.97it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/74     0.726G    0.06331    0.03635          0          9        640:  50%|█████     | 16/32 [00:01<00:01, 12.97it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/74     0.726G    0.06116     0.0355          0          5        640:  56%|█████▋    | 18/32 [00:01<00:01, 13.19it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/74     0.726G    0.06056    0.03511          0          7        640:  56%|█████▋    | 18/32 [00:01<00:01, 13.19it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/74     0.726G    0.06148    0.03566          0         13        640:  62%|██████▎   | 20/32 [00:01<00:00, 13.45it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/74     0.726G    0.06137    0.03524          0          7        640:  62%|██████▎   | 20/32 [00:01<00:00, 13.45it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/74     0.726G    0.06231    0.03579          0         13        640:  69%|██████▉   | 22/32 [00:01<00:00, 13.56it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/74     0.726G    0.06188    0.03542          0          8        640:  69%|██████▉   | 22/32 [00:01<00:00, 13.56it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/74     0.726G    0.06289    0.03582          0         11        640:  75%|███████▌  | 24/32 [00:01<00:00, 13.77it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/74     0.726G    0.06344    0.03616          0         12        640:  75%|███████▌  | 24/32 [00:01<00:00, 13.77it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/74     0.726G    0.06447    0.03724          0         19        640:  81%|████████▏ | 26/32 [00:01<00:00, 13.44it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/74     0.726G    0.06403    0.03712          0          8        640:  81%|████████▏ | 26/32 [00:02<00:00, 13.44it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/74     0.726G    0.06452    0.03714          0         11        640:  88%|████████▊ | 28/32 [00:02<00:00, 13.48it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/74     0.726G    0.06421    0.03683          0          6        640:  88%|████████▊ | 28/32 [00:02<00:00, 13.48it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/74     0.726G    0.06481    0.03691          0         10        640:  94%|█████████▍| 30/32 [00:02<00:00, 13.32it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/74     0.726G    0.06455    0.03691          0         11        640:  94%|█████████▍| 30/32 [00:02<00:00, 13.32it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/74     0.726G    0.06396    0.03738          0          6        640: 100%|██████████| 32/32 [00:02<00:00, 13.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 2/2 [00:00<00:00, 18.85it/s]
#                    all          7         17      0.577      0.482      0.512      0.165
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/32 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/74     0.726G    0.07754    0.04874          0         13        640:   0%|          | 0/32 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/74     0.726G    0.06521    0.04927          0         13        640:   6%|▋         | 2/32 [00:00<00:02, 13.92it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/74     0.726G    0.06301    0.03938          0          5        640:   6%|▋         | 2/32 [00:00<00:02, 13.92it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/74     0.726G    0.05908    0.03623          0          7        640:  12%|█▎        | 4/32 [00:00<00:02, 13.10it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/74     0.726G     0.0567    0.03347          0          6        640:  12%|█▎        | 4/32 [00:00<00:02, 13.10it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/74     0.726G    0.05614     0.0323          0          7        640:  19%|█▉        | 6/32 [00:00<00:01, 13.08it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/74     0.726G    0.05549    0.03252          0          8        640:  19%|█▉        | 6/32 [00:00<00:01, 13.08it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/74     0.726G    0.05851    0.03529          0         15        640:  25%|██▌       | 8/32 [00:00<00:01, 12.76it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/74     0.726G    0.05826    0.03745          0         15        640:  25%|██▌       | 8/32 [00:00<00:01, 12.76it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/74     0.726G    0.05774    0.03853          0         13        640:  31%|███▏      | 10/32 [00:00<00:01, 12.90it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/74     0.726G     0.0571    0.03959          0         12        640:  31%|███▏      | 10/32 [00:00<00:01, 12.90it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/74     0.726G    0.05629       0.04          0         12        640:  38%|███▊      | 12/32 [00:00<00:01, 13.27it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/74     0.726G      0.056    0.03846          0          5        640:  38%|███▊      | 12/32 [00:00<00:01, 13.27it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/74     0.726G    0.05831    0.03928          0         13        640:  44%|████▍     | 14/32 [00:01<00:01, 12.91it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/74     0.726G     0.0601    0.03945          0         11        640:  44%|████▍     | 14/32 [00:01<00:01, 12.91it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/74     0.726G    0.05937     0.0406          0         16        640:  50%|█████     | 16/32 [00:01<00:01, 12.27it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/74     0.726G     0.0584    0.03963          0          6        640:  50%|█████     | 16/32 [00:01<00:01, 12.27it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/74     0.726G    0.05957    0.03985          0         12        640:  56%|█████▋    | 18/32 [00:01<00:01, 12.63it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/74     0.726G    0.05889    0.04052          0         14        640:  56%|█████▋    | 18/32 [00:01<00:01, 12.63it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/74     0.726G    0.05855    0.03993          0          7        640:  62%|██████▎   | 20/32 [00:01<00:00, 12.49it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/74     0.726G      0.059    0.04224          0         23        640:  62%|██████▎   | 20/32 [00:01<00:00, 12.49it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/74     0.726G    0.05983    0.04308          0         15        640:  69%|██████▉   | 22/32 [00:01<00:00, 12.67it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/74     0.726G    0.06093     0.0429          0          8        640:  69%|██████▉   | 22/32 [00:01<00:00, 12.67it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/74     0.726G    0.06032    0.04233          0          9        640:  75%|███████▌  | 24/32 [00:01<00:00, 12.86it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/74     0.726G     0.0604    0.04224          0         12        640:  75%|███████▌  | 24/32 [00:01<00:00, 12.86it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/74     0.726G    0.05933    0.04142          0          7        640:  81%|████████▏ | 26/32 [00:02<00:00, 13.18it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/74     0.726G    0.05804    0.04052          0          5        640:  81%|████████▏ | 26/32 [00:02<00:00, 13.18it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/74     0.726G    0.05939    0.04014          0          8        640:  88%|████████▊ | 28/32 [00:02<00:00, 13.41it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/74     0.726G    0.05864    0.03943          0          5        640:  88%|████████▊ | 28/32 [00:02<00:00, 13.41it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/74     0.726G     0.0583    0.03942          0         11        640:  94%|█████████▍| 30/32 [00:02<00:00, 13.72it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/74     0.726G    0.05783    0.03872          0          5        640:  94%|█████████▍| 30/32 [00:02<00:00, 13.72it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/74     0.726G    0.05756    0.03871          0          5        640: 100%|██████████| 32/32 [00:02<00:00, 13.14it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 2/2 [00:00<00:00, 18.89it/s]
#                    all          7         17      0.916      0.642      0.782      0.346
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/32 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/74     0.726G     0.0677    0.04535          0         12        640:   0%|          | 0/32 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/74     0.726G    0.05626    0.04376          0         11        640:   6%|▋         | 2/32 [00:00<00:02, 13.01it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/74     0.726G    0.06307    0.04402          0         11        640:   6%|▋         | 2/32 [00:00<00:02, 13.01it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/74     0.726G    0.06675    0.04131          0          8        640:  12%|█▎        | 4/32 [00:00<00:02, 12.57it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/74     0.726G    0.06306    0.04366          0         15        640:  12%|█▎        | 4/32 [00:00<00:02, 12.57it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/74     0.726G     0.0613    0.04031          0          5        640:  19%|█▉        | 6/32 [00:00<00:01, 13.30it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/74     0.726G    0.05919    0.03797          0          6        640:  19%|█▉        | 6/32 [00:00<00:01, 13.30it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/74     0.726G    0.06171    0.04032          0         14        640:  25%|██▌       | 8/32 [00:00<00:01, 13.07it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/74     0.726G     0.0625    0.04376          0         18        640:  25%|██▌       | 8/32 [00:00<00:01, 13.07it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/74     0.726G    0.06177    0.04259          0          8        640:  31%|███▏      | 10/32 [00:00<00:01, 13.59it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/74     0.726G    0.06049    0.04136          0          8        640:  31%|███▏      | 10/32 [00:00<00:01, 13.59it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/74     0.726G    0.05814    0.03967          0          7        640:  38%|███▊      | 12/32 [00:00<00:01, 13.66it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/74     0.726G    0.05878    0.04052          0         14        640:  38%|███▊      | 12/32 [00:00<00:01, 13.66it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/74     0.726G    0.05805    0.04112          0         14        640:  44%|████▍     | 14/32 [00:01<00:01, 13.35it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/74     0.726G    0.05722    0.04038          0          8        640:  44%|████▍     | 14/32 [00:01<00:01, 13.35it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/74     0.726G    0.05659    0.04061          0         12        640:  50%|█████     | 16/32 [00:01<00:01, 13.15it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/74     0.726G    0.05781    0.04133          0         13        640:  50%|█████     | 16/32 [00:01<00:01, 13.15it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/74     0.726G    0.05668    0.03999          0          4        640:  56%|█████▋    | 18/32 [00:01<00:01, 13.53it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/74     0.726G    0.05501    0.03869          0          3        640:  56%|█████▋    | 18/32 [00:01<00:01, 13.53it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/74     0.726G    0.05597    0.04006          0         18        640:  62%|██████▎   | 20/32 [00:01<00:00, 13.72it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/74     0.726G    0.05573     0.0397          0          9        640:  62%|██████▎   | 20/32 [00:01<00:00, 13.72it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/74     0.726G    0.05512    0.03945          0          8        640:  69%|██████▉   | 22/32 [00:01<00:00, 13.58it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/74     0.726G    0.05402    0.03842          0          4        640:  69%|██████▉   | 22/32 [00:01<00:00, 13.58it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/74     0.726G    0.05532    0.03873          0         12        640:  75%|███████▌  | 24/32 [00:01<00:00, 13.81it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/74     0.726G     0.0546    0.03808          0          5        640:  75%|███████▌  | 24/32 [00:01<00:00, 13.81it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/74     0.726G    0.05458    0.03748          0          6        640:  81%|████████▏ | 26/32 [00:01<00:00, 14.09it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/74     0.726G    0.05428    0.03713          0          9        640:  81%|████████▏ | 26/32 [00:01<00:00, 14.09it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/74     0.726G      0.054    0.03717          0         11        640:  88%|████████▊ | 28/32 [00:02<00:00, 14.14it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/74     0.726G    0.05403    0.03726          0         11        640:  88%|████████▊ | 28/32 [00:02<00:00, 14.14it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/74     0.726G    0.05465    0.03765          0         13        640:  94%|█████████▍| 30/32 [00:02<00:00, 13.96it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/74     0.726G    0.05457    0.03708          0          6        640:  94%|█████████▍| 30/32 [00:02<00:00, 13.96it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/74     0.726G    0.05389    0.03653          0          2        640: 100%|██████████| 32/32 [00:02<00:00, 13.63it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 2/2 [00:00<00:00, 17.51it/s]
#                    all          7         17       0.48      0.653        0.6      0.271
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/32 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/74     0.726G    0.04012    0.02629          0          8        640:   0%|          | 0/32 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/74     0.726G    0.05414    0.04371          0         14        640:   6%|▋         | 2/32 [00:00<00:02, 13.26it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/74     0.726G    0.06129    0.04203          0          9        640:   6%|▋         | 2/32 [00:00<00:02, 13.26it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/74     0.726G    0.05706     0.0406          0          9        640:  12%|█▎        | 4/32 [00:00<00:02, 13.26it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/74     0.726G    0.05461      0.042          0         12        640:  12%|█▎        | 4/32 [00:00<00:02, 13.26it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/74     0.726G    0.05577    0.04127          0          9        640:  19%|█▉        | 6/32 [00:00<00:02, 12.57it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/74     0.726G      0.055    0.04033          0         11        640:  19%|█▉        | 6/32 [00:00<00:02, 12.57it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/74     0.726G     0.0543    0.03844          0          7        640:  25%|██▌       | 8/32 [00:00<00:01, 13.03it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/74     0.726G    0.05686    0.03762          0         10        640:  25%|██▌       | 8/32 [00:00<00:01, 13.03it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/74     0.726G    0.05959    0.03917          0         16        640:  31%|███▏      | 10/32 [00:00<00:01, 13.24it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/74     0.726G    0.05855    0.03849          0          7        640:  31%|███▏      | 10/32 [00:00<00:01, 13.24it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/74     0.726G    0.05794    0.03781          0          8        640:  38%|███▊      | 12/32 [00:00<00:01, 12.26it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/74     0.726G    0.05741    0.03796          0         10        640:  38%|███▊      | 12/32 [00:01<00:01, 12.26it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/74     0.726G    0.05655    0.03804          0         11        640:  44%|████▍     | 14/32 [00:01<00:01, 10.86it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/74     0.726G    0.05421    0.03672          0          5        640:  44%|████▍     | 14/32 [00:01<00:01, 10.86it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/74     0.726G    0.05393    0.03609          0          8        640:  50%|█████     | 16/32 [00:01<00:01,  9.90it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/74     0.726G    0.05334    0.03608          0         11        640:  50%|█████     | 16/32 [00:01<00:01,  9.90it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/74     0.726G    0.05313    0.03612          0         10        640:  56%|█████▋    | 18/32 [00:01<00:01,  9.69it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/74     0.726G    0.05279    0.03709          0         16        640:  59%|█████▉    | 19/32 [00:01<00:01,  9.58it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/74     0.726G    0.05208    0.03663          0          6        640:  62%|██████▎   | 20/32 [00:01<00:01,  9.61it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/74     0.726G    0.05238    0.03727          0         13        640:  66%|██████▌   | 21/32 [00:01<00:01,  9.61it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/74     0.726G    0.05205    0.03804          0         15        640:  69%|██████▉   | 22/32 [00:02<00:01,  9.53it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/74     0.726G    0.05168    0.03824          0         12        640:  72%|███████▏  | 23/32 [00:02<00:00,  9.61it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/74     0.726G    0.05176    0.03763          0          7        640:  75%|███████▌  | 24/32 [00:02<00:00,  9.39it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/74     0.726G    0.05164    0.03821          0         16        640:  78%|███████▊  | 25/32 [00:02<00:00,  8.91it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/74     0.726G    0.05201    0.03794          0          9        640:  81%|████████▏ | 26/32 [00:02<00:00,  8.48it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/74     0.726G    0.05334     0.0374          0          7        640:  84%|████████▍ | 27/32 [00:02<00:00,  8.60it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/74     0.726G    0.05395    0.03774          0         13        640:  84%|████████▍ | 27/32 [00:02<00:00,  8.60it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/74     0.726G    0.05472     0.0378          0         10        640:  91%|█████████ | 29/32 [00:02<00:00,  8.74it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/74     0.726G    0.05428     0.0374          0          6        640:  94%|█████████▍| 30/32 [00:02<00:00,  8.90it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/74     0.726G    0.05375    0.03707          0          8        640:  97%|█████████▋| 31/32 [00:03<00:00,  8.74it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/74     0.726G    0.05363    0.03654          0          2        640: 100%|██████████| 32/32 [00:03<00:00, 10.05it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 2/2 [00:00<00:00, 14.53it/s]
#                    all          7         17      0.511      0.706       0.55      0.195
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/32 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/74     0.726G    0.05758    0.04155          0         10        640:   3%|▎         | 1/32 [00:00<00:04,  7.11it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/74     0.726G    0.04431    0.02966          0          5        640:   6%|▋         | 2/32 [00:00<00:03,  7.93it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/74     0.726G    0.04639    0.03617          0         13        640:   9%|▉         | 3/32 [00:00<00:03,  8.75it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/74     0.726G    0.04649    0.03243          0          6        640:  12%|█▎        | 4/32 [00:00<00:03,  8.79it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/74     0.726G    0.04923     0.0353          0         12        640:  16%|█▌        | 5/32 [00:00<00:03,  7.29it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/74     0.726G    0.04847    0.03563          0         11        640:  19%|█▉        | 6/32 [00:00<00:03,  7.72it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/74     0.726G    0.04831    0.03393          0          6        640:  22%|██▏       | 7/32 [00:00<00:03,  6.95it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/74     0.726G    0.04849    0.03407          0          9        640:  25%|██▌       | 8/32 [00:01<00:03,  7.14it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/74     0.726G    0.04989     0.0365          0         15        640:  28%|██▊       | 9/32 [00:01<00:03,  7.13it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/74     0.726G    0.05012    0.03604          0          9        640:  31%|███▏      | 10/32 [00:01<00:02,  7.44it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/74     0.726G    0.04984    0.03595          0         10        640:  34%|███▍      | 11/32 [00:01<00:02,  7.73it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...
#   with torch.cuda.amp.autocast(amp):
#       74/74     0.726G    0.02757     0.0322          0          7        640:  19%|█▉        | 6/32 [00:00<00:02, 12.52it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       74/74     0.726G    0.02747    0.03471          0         17        640:  25%|██▌       | 8/32 [00:00<00:01, 13.03it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       74/74     0.726G     0.0286     0.0384          0         17        640:  25%|██▌       | 8/32 [00:00<00:01, 13.03it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       74/74     0.726G    0.02711     0.0358          0          4        640:  31%|███▏      | 10/32 [00:00<00:01, 12.83it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       74/74     0.726G    0.02731     0.0352          0         11        640:  31%|███▏      | 10/32 [00:00<00:01, 12.83it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       74/74     0.726G    0.02855    0.03452          0          7        640:  38%|███▊      | 12/32 [00:00<00:01, 12.45it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       74/74     0.726G    0.02727    0.03294          0          5        640:  38%|███▊      | 12/32 [00:01<00:01, 12.45it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       74/74     0.726G    0.02685    0.03252          0         11        640:  44%|████▍     | 14/32 [00:01<00:01, 12.77it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       74/74     0.726G    0.02827    0.03465          0         19        640:  44%|████▍     | 14/32 [00:01<00:01, 12.77it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       74/74     0.726G    0.02789    0.03344          0          5        640:  50%|█████     | 16/32 [00:01<00:01, 12.29it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       74/74     0.726G    0.02882    0.03345          0         11        640:  50%|█████     | 16/32 [00:01<00:01, 12.29it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       74/74     0.726G    0.02848    0.03403          0         13        640:  56%|█████▋    | 18/32 [00:01<00:01, 12.37it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       74/74     0.726G    0.02834     0.0336          0          6        640:  56%|█████▋    | 18/32 [00:01<00:01, 12.37it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       74/74     0.726G      0.028    0.03294          0          7        640:  62%|██████▎   | 20/32 [00:01<00:00, 12.19it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       74/74     0.726G    0.02814     0.0333          0         14        640:  62%|██████▎   | 20/32 [00:01<00:00, 12.19it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       74/74     0.726G    0.02865    0.03436          0         15        640:  69%|██████▉   | 22/32 [00:01<00:00, 12.57it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       74/74     0.726G    0.02819    0.03362          0          6        640:  69%|██████▉   | 22/32 [00:01<00:00, 12.57it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       74/74     0.726G    0.02821    0.03304          0          7        640:  75%|███████▌  | 24/32 [00:01<00:00, 11.91it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       74/74     0.726G    0.02731    0.03218          0          3        640:  75%|███████▌  | 24/32 [00:01<00:00, 11.91it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       74/74     0.726G    0.02842    0.03211          0         11        640:  81%|████████▏ | 26/32 [00:02<00:00, 12.48it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       74/74     0.726G    0.02811    0.03182          0          7        640:  81%|████████▏ | 26/32 [00:02<00:00, 12.48it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       74/74     0.726G    0.02803    0.03214          0         12        640:  88%|████████▊ | 28/32 [00:02<00:00, 12.27it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       74/74     0.726G    0.02775    0.03208          0         12        640:  88%|████████▊ | 28/32 [00:02<00:00, 12.27it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       74/74     0.726G    0.02757    0.03307          0         21        640:  94%|█████████▍| 30/32 [00:02<00:00, 13.03it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       74/74     0.726G    0.02809    0.03307          0         13        640:  94%|█████████▍| 30/32 [00:02<00:00, 13.03it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       74/74     0.726G    0.02801    0.03313          0          5        640: 100%|██████████| 32/32 [00:02<00:00, 12.60it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 2/2 [00:00<00:00, 21.66it/s]
#                    all          7         17      0.831      0.706      0.773       0.44
#
# 75 epochs completed in 0.082 hours.
# Optimizer stripped from runs/train/exp3/weights/last.pt, 14.4MB
# Optimizer stripped from runs/train/exp3/weights/best.pt, 14.4MB
#
# Validating runs/train/exp3/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 2/2 [00:00<00:00,  8.84it/s]
#                    all          7         17       0.81      0.754      0.811      0.515
# Results saved to runs/train/exp3
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml OfflineExperiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : exp
# COMET INFO:     url                   : [OfflineExperiment will get URL after upload]
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     loss [233]                 : (0.03911229223012924, 0.3856660723686218)
# COMET INFO:     metrics/mAP_0.5 [150]      : (0.009814531615974342, 0.8314575545049916)
# COMET INFO:     metrics/mAP_0.5:0.95 [150] : (0.0017352052409073109, 0.5147069461247817)
# COMET INFO:     metrics/precision [150]    : (0.004761904761904762, 0.9160501290130919)
# COMET INFO:     metrics/recall [150]       : (0.3936520554167612, 0.8235294117647058)
# COMET INFO:     train/box_loss [150]       : (0.02664475329220295, 0.08705173432826996)
# COMET INFO:     train/cls_loss             : 0.0
# COMET INFO:     train/obj_loss [150]       : (0.027735421434044838, 0.04552232474088669)
# COMET INFO:     val/box_loss [150]         : (0.023025693371891975, 0.08456504344940186)
# COMET INFO:     val/cls_loss               : 0.0
# COMET INFO:     val/obj_loss [150]         : (0.012627720832824707, 0.025835037231445312)
# COMET INFO:     x/lr0 [150]                : (0.0003639999999999995, 0.0721)
# COMET INFO:     x/lr1 [150]                : (0.0003639999999999995, 0.009604)
# COMET INFO:     x/lr2 [150]                : (0.0003639999999999995, 0.009604)
# COMET INFO:   Others:
# COMET INFO:     Name                        : exp
# COMET INFO:     comet_log_batch_metrics     : False
# COMET INFO:     comet_log_confusion_matrix  : True
# COMET INFO:     comet_log_per_class_metrics : False
# COMET INFO:     comet_max_image_uploads     : 100
# COMET INFO:     comet_mode                  : online
# COMET INFO:     comet_model_name            : yolov5
# COMET INFO:     hasNestedParams             : True
# COMET INFO:     offline_experiment          : True
# COMET INFO:   Parameters:
# COMET INFO:     anchor_t            : 4.0
# COMET INFO:     artifact_alias      : latest
# COMET INFO:     batch_size          : 2
# COMET INFO:     bbox_interval       : -1
# COMET INFO:     box                 : 0.05
# COMET INFO:     bucket              :
# COMET INFO:     cfg                 :
# COMET INFO:     cls                 : 0.006250000000000001
# COMET INFO:     cls_pw              : 1.0
# COMET INFO:     copy_paste          : 0.0
# COMET INFO:     cos_lr              : False
# COMET INFO:     degrees             : 0.0
# COMET INFO:     device              :
# COMET INFO:     entity              : None
# COMET INFO:     evolve              : None
# COMET INFO:     evolve_population   : data/hyps
# COMET INFO:     exist_ok            : False
# COMET INFO:     fl_gamma            : 0.0
# COMET INFO:     fliplr              : 0.5
# COMET INFO:     flipud              : 0.0
# COMET INFO:     freeze              : [0]
# COMET INFO:     hsv_h               : 0.015
# COMET INFO:     hsv_s               : 0.7
# COMET INFO:     hsv_v               : 0.4
# COMET INFO:     hyp|anchor_t        : 4.0
# COMET INFO:     hyp|box             : 0.05
# COMET INFO:     hyp|cls             : 0.5
# COMET INFO:     hyp|cls_pw          : 1.0
# COMET INFO:     hyp|copy_paste      : 0.0
# COMET INFO:     hyp|degrees         : 0.0
# COMET INFO:     hyp|fl_gamma        : 0.0
# COMET INFO:     hyp|fliplr          : 0.5
# COMET INFO:     hyp|flipud          : 0.0
# COMET INFO:     hyp|hsv_h           : 0.015
# COMET INFO:     hyp|hsv_s           : 0.7
# COMET INFO:     hyp|hsv_v           : 0.4
# COMET INFO:     hyp|iou_t           : 0.2
# COMET INFO:     hyp|lr0             : 0.01
# COMET INFO:     hyp|lrf             : 0.01
# COMET INFO:     hyp|mixup           : 0.0
# COMET INFO:     hyp|momentum        : 0.937
# COMET INFO:     hyp|mosaic          : 1.0
# COMET INFO:     hyp|obj             : 1.0
# COMET INFO:     hyp|obj_pw          : 1.0
# COMET INFO:     hyp|perspective     : 0.0
# COMET INFO:     hyp|scale           : 0.5
# COMET INFO:     hyp|shear           : 0.0
# COMET INFO:     hyp|translate       : 0.1
# COMET INFO:     hyp|warmup_bias_lr  : 0.1
# COMET INFO:     hyp|warmup_epochs   : 3.0
# COMET INFO:     hyp|warmup_momentum : 0.8
# COMET INFO:     hyp|weight_decay    : 0.0005
# COMET INFO:     image_weights       : False
# COMET INFO:     imgsz               : 640
# COMET INFO:     iou_t               : 0.2
# COMET INFO:     label_smoothing     : 0.0
# COMET INFO:     local_rank          : -1
# COMET INFO:     lr0                 : 0.01
# COMET INFO:     lrf                 : 0.01
# COMET INFO:     mixup               : 0.0
# COMET INFO:     momentum            : 0.937
# COMET INFO:     mosaic              : 1.0
# COMET INFO:     multi_scale         : False
# COMET INFO:     name                : exp
# COMET INFO:     ndjson_console      : False
# COMET INFO:     ndjson_file         : False
# COMET INFO:     noautoanchor        : False
# COMET INFO:     noplots             : False
# COMET INFO:     nosave              : False
# COMET INFO:     noval               : False
# COMET INFO:     obj                 : 1.0
# COMET INFO:     obj_pw              : 1.0
# COMET INFO:     optimizer           : SGD
# COMET INFO:     patience            : 100
# COMET INFO:     perspective         : 0.0
# COMET INFO:     project             : runs/train
# COMET INFO:     quad                : False
# COMET INFO:     rect                : False
# COMET INFO:     resume              : False
# COMET INFO:     resume_evolve       : None
# COMET INFO:     save_dir            : runs/train/exp3
# COMET INFO:     save_period         : -1
# COMET INFO:     scale               : 0.5
# COMET INFO:     seed                : 0
# COMET INFO:     shear               : 0.0
# COMET INFO:     single_cls          : False
# COMET INFO:     sync_bn             : False
# COMET INFO:     translate           : 0.1
# COMET INFO:     upload_dataset      : False
# COMET INFO:     val_conf_threshold  : 0.001
# COMET INFO:     val_iou_threshold   : 0.6
# COMET INFO:     warmup_bias_lr      : 0.1
# COMET INFO:     warmup_epochs       : 3.0
# COMET INFO:     warmup_momentum     : 0.8
# COMET INFO:     weight_decay        : 0.0005
# COMET INFO:     workers             : 8
# COMET INFO:   Uploads:
# COMET INFO:     asset               : 13 (1.13 MB)
# COMET INFO:     confusion-matrix    : 1
# COMET INFO:     environment details : 1
# COMET INFO:     git metadata        : 1
# COMET INFO:     images              : 6
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:     os packages         : 1
# COMET INFO:
# COMET INFO: Still saving offline stats to messages file before program termination (may take up to 120 seconds)
# COMET INFO: Begin archiving the offline data.
# COMET INFO: To upload this offline experiment, run:
#     comet upload /content/yolov5/.cometml-runs/0360bf9dbcd74555953c024bf60673bc.zip

# %% [markdown]
# # 4. Visualize

# %% [markdown]
# ## Comet Logging and Visualization 🌟 NEW
#
# [Comet](https://www.comet.com/site/lp/yolov5-with-comet/?utm_source=yolov5&utm_medium=partner&utm_campaign=partner_yolov5_2022&utm_content=yolov5_colab) is now fully integrated with YOLOv5. Track and visualize model metrics in real time, save your hyperparameters, datasets, and model checkpoints, and visualize your model predictions with [Comet Custom Panels](https://www.comet.com/docs/v2/guides/comet-dashboard/code-panels/about-panels/?utm_source=yolov5&utm_medium=partner&utm_campaign=partner_yolov5_2022&utm_content=yolov5_colab)! Comet makes sure you never lose track of your work and makes it easy to share results and collaborate across teams of all sizes!
#
# Getting started is easy:
# ```shell
# pip install comet_ml  # 1. install
# export COMET_API_KEY=<Your API Key>  # 2. paste API key
# python train.py --img 640 --epochs 3 --data coco128.yaml --weights yolov5s.pt  # 3. train
# ```
# To learn more about all of the supported Comet features for this integration, check out the [Comet Tutorial](https://docs.ultralytics.com/yolov5/tutorials/comet_logging_integration). If you'd like to learn more about Comet, head over to our [documentation](https://www.comet.com/docs/v2/?utm_source=yolov5&utm_medium=partner&utm_campaign=partner_yolov5_2022&utm_content=yolov5_colab). Get started by trying out the Comet Colab Notebook:
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1RG0WOQyxlDlo5Km8GogJpIEJlg_5lyYO?usp=sharing)
#
# <a href="https://bit.ly/yolov5-readme-comet2">
# <img alt="Comet Dashboard" src="https://user-images.githubusercontent.com/26833433/202851203-164e94e1-2238-46dd-91f8-de020e9d6b41.png" width="1280"/></a>

# %% [markdown]
# ## ClearML Logging and Automation 🌟 NEW
#
# [ClearML](https://cutt.ly/yolov5-notebook-clearml) is completely integrated into YOLOv5 to track your experimentation, manage dataset versions and even remotely execute training runs. To enable ClearML (check cells above):
#
# - `pip install clearml`
# - run `clearml-init` to connect to a ClearML server (**deploy your own [open-source server](https://github.com/allegroai/clearml-server)**, or use our [free hosted server](https://cutt.ly/yolov5-notebook-clearml))
#
# You'll get all the great expected features from an experiment manager: live updates, model upload, experiment comparison etc. but ClearML also tracks uncommitted changes and installed packages for example. Thanks to that ClearML Tasks (which is what we call experiments) are also reproducible on different machines! With only 1 extra line, we can schedule a YOLOv5 training task on a queue to be executed by any number of ClearML Agents (workers).
#
# You can use ClearML Data to version your dataset and then pass it to YOLOv5 simply using its unique ID. This will help you keep track of your data without adding extra hassle. Explore the [ClearML Tutorial](https://docs.ultralytics.com/yolov5/tutorials/clearml_logging_integration) for details!
#
# <a href="https://cutt.ly/yolov5-notebook-clearml">
# <img alt="ClearML Experiment Management UI" src="https://github.com/thepycoder/clearml_screenshots/raw/main/scalars.jpg" width="1280"/></a>

# %% [markdown]
# ## Local Logging
#
# Training results are automatically logged with [Tensorboard](https://www.tensorflow.org/tensorboard) and [CSV](https://github.com/ultralytics/yolov5/pull/4148) loggers to `runs/train`, with a new experiment directory created for each new training as `runs/train/exp2`, `runs/train/exp3`, etc.
#
# This directory contains train and val statistics, mosaics, labels, predictions and augmentated mosaics, as well as metrics and charts including precision-recall (PR) curves and confusion matrices.
#
# <img alt="Local logging results" src="https://user-images.githubusercontent.com/26833433/183222430-e1abd1b7-782c-4cde-b04d-ad52926bf818.jpg" width="1280"/>

# %% [markdown]
# # Environments
#
# YOLOv5 may be run in any of the following up-to-date verified environments (with all dependencies including [CUDA](https://developer.nvidia.com/cuda)/[CUDNN](https://developer.nvidia.com/cudnn), [Python](https://www.python.org/) and [PyTorch](https://pytorch.org/) preinstalled):
#
# - **Notebooks** with free GPU: <a href="https://bit.ly/yolov5-paperspace-notebook"><img src="https://assets.paperspace.io/img/gradient-badge.svg" alt="Run on Gradient"></a> <a href="https://colab.research.google.com/github/ultralytics/yolov5/blob/master/tutorial.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a> <a href="https://www.kaggle.com/models/ultralytics/yolov5"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" alt="Open In Kaggle"></a>
# - **Google Cloud** Deep Learning VM. See [GCP Quickstart Guide](https://docs.ultralytics.com/yolov5/environments/google_cloud_quickstart_tutorial/)
# - **Amazon** Deep Learning AMI. See [AWS Quickstart Guide](https://docs.ultralytics.com/yolov5/environments/aws_quickstart_tutorial/)
# - **Docker Image**. See [Docker Quickstart Guide](https://docs.ultralytics.com/yolov5/environments/docker_image_quickstart_tutorial/) <a href="https://hub.docker.com/r/ultralytics/yolov5"><img src="https://img.shields.io/docker/pulls/ultralytics/yolov5?logo=docker" alt="Docker Pulls"></a>

# %% [markdown]
# # Status
#
# ![YOLOv5 CI](https://github.com/ultralytics/yolov5/actions/workflows/ci-testing.yml/badge.svg)
#
# If this badge is green, all [YOLOv5 GitHub Actions](https://github.com/ultralytics/yolov5/actions) Continuous Integration (CI) tests are currently passing. CI tests verify correct operation of YOLOv5 training ([train.py](https://github.com/ultralytics/yolov5/blob/master/train.py)), testing ([val.py](https://github.com/ultralytics/yolov5/blob/master/val.py)), inference ([detect.py](https://github.com/ultralytics/yolov5/blob/master/detect.py)) and export ([export.py](https://github.com/ultralytics/yolov5/blob/master/export.py)) on macOS, Windows, and Ubuntu every 24 hours and on every commit.

# %% [markdown]
# # Appendix
#
# Additional content below.

# %%
# YOLOv5 PyTorch HUB Inference (DetectionModels only)
import torch

model = torch.hub.load('ultralytics/yolov5', 'yolov5s', force_reload=True, trust_repo=True)  # or yolov5n - yolov5x6 or custom
im = '/content/yolov5/data/data/test/images/22_jpg.rf.f75506b4b0c57b5c6a9537fc70b458ee.jpg'  # file, Path, PIL.Image, OpenCV, nparray, list
results = model(im)  # inference
results.print()  # or .show(), .save(), .crop(), .pandas(), etc.
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /root/.cache/torch/hub/master.zip
# YOLOv5 🚀 v7.0-378-g2f74455a Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# image 1/1: 416x416 2 birds
# Speed: 5.9ms pre-process, 13.2ms inference, 2.2ms NMS per image at shape (1, 3, 640, 640)
